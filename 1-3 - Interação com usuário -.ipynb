# %%
# nome da variável é "x" que armazena valor em espaço da memória
x = 10

print (x) # utiliza a referência
# Out:
# 10

# %%
print ("conhecendo o comando Print")

x = 8
print (x)
# Out:
# conhecendo o comando Print
# 8

# %%
y = 10
soma = x + y
print (soma)
# Out:
# 18

# %% [markdown]
# ## Concatenação

# %%
x = 5
print ('O valor de x é ', x)
# Out:
# O valor de x é  5

# %%
print ('O valor de x é', x, 'e o dobro é ', x * 2)
# Out:
# O valor de x é 5 e o dobro é  10

# %%
nome = 'Fernando Augusto'
print (nome)
# Out:
# Fernando Augusto

# %%
print('Eu,', nome, 'tirei', x, 'na prova de Python)')
# Out:
# Eu, Fernando Augusto tirei  5 na prova de Python)

# %%
x = 10
type (x)
print ('x', type(x))

nome = 'Fernando'
print('nome', type(nome))

num = '100'
num_convert = int(num) #converter variável
print('num', type(num))
print('num_convert', type(num_convert))

num_float = float(num)
print('num_float', type(num_float))
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_convert <class 'int'>
# num_float <class 'float'>

# %% [markdown]
# ## Input
#   * Armazenar a informação digitada pelo usuário em uma variável
#   * O dado armazenado sempre será um texto

# %%
nome = input("Digite o nome do usuário: ") # Aguarda o usuário digitar algo
print(nome)
# Out:
# Digite o nome do usuário: Fernando
# Fernando

# %%
valor = input("Digite a nota: ")
print(nome, 'sua nota foi: ', valor)
# Out:
# Digite a nota: 9
# Fernando sua nota foi:  9

# %%
valor = input("Digite o valor do produto: ")
print(valor)
# Out:
# Digite o valor do produto: 100
# 100

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-4693ea9a50ed> in <cell line: 1>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
valor_convert = int(valor)
desconto = valor_convert - 5
print(desconto)
# Out:
# 95
